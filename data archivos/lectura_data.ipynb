# %%
https://raw.githubusercontent.com/sightes/COFFETALKS/main/data%20archivos/data.csv

https://raw.githubusercontent.com/sightes/COFFETALKS/main/data%20archivos/data.pkl

https://raw.githubusercontent.com/sightes/COFFETALKS/main/data%20archivos/data.xlsx

# %%
import pandas as pd 
df=pd.read_csv('encuesta.txt',sep='\s+',)
df
# Out:
#                                   ID  asistio  Tarea  Comportamiento Pago
# 0    cef3615d61b202f1dc794ef2746df14        1    1.0             0.0   si
# 1    323e5a13644d18185c743c241407754        0    0.0             NaN   no
# 2    b29a107e5cd062e654a63764157461d        0    0.0             NaN   no
# 3   04a11e4bcb573a1261eb0d9948d32637        1    0.0             0.0   si
# 4    9368291c3d5d5f5c8cdb1a575e18bec        1    0.0             0.0   si
# 5    dd0e77eab270e4b67c19b0d6bbf621b        0    0.0             NaN   no
# 6    7599c0aa419b59fd11ffede98a3665d        0    0.0             NaN   si
# 7    6dff182b452487f07a47596f314bddc        0    1.0             NaN   si
# 8    9dc233fed1c6eb2432672ab4bb39249        0    0.0             NaN   no
# 9   265fa78a1fb2409ff5416aec3c4f950d        1    0.0             0.0   si
# 10  3b461f95fe50be35b927c255b3f7dc3a        1    1.0             1.0   no
# 11  e786f1288887afb309eb913d28ffd6b0        1    0.0             0.0   si
# ...

# %%
import pandas as pd
pd.read_excel('data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19504/3181699118.py in <module>
#       1 import pandas as pd
# ----> 2 pd.read_excel('data.xlsx')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
import time
inicio = time.time()
df = pd.read_pickle('data.pkl', 'gzip')
fin = time.time()
print(fin-inicio)
# Out:
# 0.04776167869567871

# %%
import time
inicio = time.time()
df=pd.read_csv('data.csv',sep='|',)
fin = time.time()
print(fin-inicio)
# Out:
# 0.14113354682922363
