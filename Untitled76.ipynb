# %% [markdown]
# <a href="https://colab.research.google.com/github/sightes/COFFETALKS/blob/main/Untitled76.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !jar xvf Archivo.zip

# %%
import warnings
warnings.filterwarnings{'ignore'}

# %%
import os
import glob
import pandas as pd
file_list=glob.glob(os.getcwd()+ '/dump/*.csv')
append_csv=[]
for f in file_list :
  append_csv.append(pd.read_csv(f,index_col=None,header=0).drop(columns='Unnamed: 0'))

# %%
df_lyrics = pd.concat(append_csv)

# %%
df_lyrics.columns=['artist','genre','song','lyrics']
df_lyrics
# Out:
#           artist   genre                      song  \
# 0    Killer Mike  hiphop           Monster (Intro)
# 1    Killer Mike  hiphop                   Monster
# 2    Killer Mike  hiphop            Akshon (Yeah!)
# 3    Killer Mike  hiphop               Rap Is Dead
# 4    Killer Mike  hiphop           Scared Straight
# ..           ...     ...                       ...
# 129        Oasis    rock                Soldier On
# 130        Oasis    rock   Lord Don't Slow Me Down
# 131        Oasis    rock        Boy With The Blues
# 132        Oasis    rock          I Believe In All
# 133        Oasis    rock  Those Swollen Hand Blues
#
#                                                 lyrics
# 0    Peace will never tame the hatred in me \n I'm ...
# 1    Peace will never tame the hatrid of me \n I'm ...
# 2    Let's do that shit \n Yeah! Killer keeps it ho...
# 3    Big is dead, Pac is dead \n My music's dead, a...
# 4    (Killer Mike talking on the phone) \n Aight......
# ..                                                 ...
# 129  Hold the line \n Friend of mine \n Sing a song...
# 130  I'm tired and I'm sick. \n Got a habit that I ...
# 131  You sing, you shout \n You turn the world arou...
# 132  I can take 'em all \n So I leave you with this...
# 133  I can't see the wood for the trees \n Life is ...
#
# [9489 rows x 4 columns]

# %%
# 2
from sklearn.feature_extraction.text import CountVectorizer
counter=CountVectorizer(stop_words='english',max_df=0.3,min_df=0.2,max_features=5000)
transformed_feats=counter.fit_transform(df_lyrics['lyrics'].values)

# %%
#3
from sklearn.decomposition import LatentDirichletAllocation

# %%
model=LatentDirichletAllocation(learning_method='online',n_components=5,learning_decay=0.7)

# %%
model.fit(transformed_feats)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=5)

# %%
model.perplexity(transformed_feats)
# Out:
# 14.558884809511255

# %%
for topic_id, topic_name in enumerate(model.components_):
   print("tópico: {}".format(topic_id + 1))
   print(" ".join([counter.get_feature_names()[i] for i in
topic_name.argsort()[:-15 - 1: -1]]))
# Out:
# tópico: 1
# ain right tell think say way man life ve look want day need baby wanna
# tópico: 2
# man wanna need look day way want say tell ve right think feel life baby
# tópico: 3
# oh baby ve tell need want think look feel right way say life yeah man
# tópico: 4
# yeah way right say need feel day baby look want oh tell think man ain
# tópico: 5
# want life way feel say ve day need think look tell right wanna oh baby

# %%
#5 a

# %%
fit_lda=model.transform(transformed_feats)

# %%
topics=list(map(lambda x: "topic {}".format(x),range(1,model.n_components+1)))

# %%
import numpy as np

# %%
docs_topics=pd.DataFrame(np.round(fit_lda,3),columns=topics,index=df_lyrics.index)

# %%
docs_topics
# Out:
#      topic 1  topic 2  topic 3  topic 4  topic 5
# 0      0.004    0.790    0.021    0.181    0.004
# 1      0.004    0.788    0.004    0.200    0.004
# 2      0.698    0.115    0.033    0.002    0.152
# 3      0.870    0.087    0.008    0.034    0.001
# 4      0.789    0.001    0.001    0.001    0.208
# ..       ...      ...      ...      ...      ...
# 129    0.005    0.005    0.979    0.005    0.005
# 130    0.092    0.350    0.005    0.005    0.548
# 131    0.009    0.009    0.009    0.536    0.438
# 132    0.010    0.066    0.010    0.904    0.010
# 133    0.009    0.009    0.009    0.798    0.175
#
# [9489 rows x 5 columns]

# %%
df_lyrics
# Out:
#           artist   genre                      song  \
# 0    Killer Mike  hiphop           Monster (Intro)
# 1    Killer Mike  hiphop                   Monster
# 2    Killer Mike  hiphop            Akshon (Yeah!)
# 3    Killer Mike  hiphop               Rap Is Dead
# 4    Killer Mike  hiphop           Scared Straight
# ..           ...     ...                       ...
# 129        Oasis    rock                Soldier On
# 130        Oasis    rock   Lord Don't Slow Me Down
# 131        Oasis    rock        Boy With The Blues
# 132        Oasis    rock          I Believe In All
# 133        Oasis    rock  Those Swollen Hand Blues
#
#                                                 lyrics
# 0    Peace will never tame the hatred in me \n I'm ...
# 1    Peace will never tame the hatrid of me \n I'm ...
# 2    Let's do that shit \n Yeah! Killer keeps it ho...
# 3    Big is dead, Pac is dead \n My music's dead, a...
# 4    (Killer Mike talking on the phone) \n Aight......
# ..                                                 ...
# 129  Hold the line \n Friend of mine \n Sing a song...
# 130  I'm tired and I'm sick. \n Got a habit that I ...
# 131  You sing, you shout \n You turn the world arou...
# 132  I can take 'em all \n So I leave you with this...
# 133  I can't see the wood for the trees \n Life is ...
#
# [9489 rows x 4 columns]

# %%
concat_cancion=pd.concat([df_lyrics,docs_topics],axis=1)

# %%
concat_cancion['mejor']=np.argmax(docs_topics.values,axis=1)+1

# %%
concat_cancion
# Out:
#           artist   genre                      song  \
# 0    Killer Mike  hiphop           Monster (Intro)
# 1    Killer Mike  hiphop                   Monster
# 2    Killer Mike  hiphop            Akshon (Yeah!)
# 3    Killer Mike  hiphop               Rap Is Dead
# 4    Killer Mike  hiphop           Scared Straight
# ..           ...     ...                       ...
# 129        Oasis    rock                Soldier On
# 130        Oasis    rock   Lord Don't Slow Me Down
# 131        Oasis    rock        Boy With The Blues
# 132        Oasis    rock          I Believe In All
# 133        Oasis    rock  Those Swollen Hand Blues
#
#                                                 lyrics  topic 1  topic 2  \
# 0    Peace will never tame the hatred in me \n I'm ...    0.004    0.790
# 1    Peace will never tame the hatrid of me \n I'm ...    0.004    0.788
# 2    Let's do that shit \n Yeah! Killer keeps it ho...    0.698    0.115
# 3    Big is dead, Pac is dead \n My music's dead, a...    0.870    0.087
# 4    (Killer Mike talking on the phone) \n Aight......    0.789    0.001
# ..                                                 ...      ...      ...
# 129  Hold the line \n Friend of mine \n Sing a song...    0.005    0.005
# 130  I'm tired and I'm sick. \n Got a habit that I ...    0.092    0.350
# 131  You sing, you shout \n You turn the world arou...    0.009    0.009
# 132  I can take 'em all \n So I leave you with this...    0.010    0.066
# 133  I can't see the wood for the trees \n Life is ...    0.009    0.009
#
#      topic 3  topic 4  topic 5  mejor
# 0      0.021    0.181    0.004      2
# 1      0.004    0.200    0.004      2
# 2      0.033    0.002    0.152      1
# 3      0.008    0.034    0.001      1
# 4      0.001    0.001    0.208      1
# ..       ...      ...      ...    ...
# 129    0.979    0.005    0.005      3
# 130    0.005    0.005    0.548      5
# 131    0.009    0.536    0.438      4
# 132    0.010    0.904    0.010      4
# 133    0.009    0.798    0.175      4
#
# [9489 rows x 10 columns]

# %%
def mixture(df,artist):
  return df[df['artist']==artist].loc[:,'topic 1' : 'topic 5']

Emminem = mixture (concat_cancion,'Britney Spears')

# %%
Emminem
# Out:
#      topic 1  topic 2  topic 3  topic 4  topic 5
# 0      0.004    0.177    0.004    0.811    0.004
# 1      0.003    0.004    0.004    0.266    0.724
# 2      0.005    0.005    0.144    0.381    0.465
# 3      0.697    0.001    0.017    0.051    0.234
# 4      0.004    0.004    0.004    0.926    0.062
# ..       ...      ...      ...      ...      ...
# 318    0.355    0.008    0.008    0.008    0.620
# 319    0.286    0.003    0.003    0.377    0.330
# 320    0.003    0.127    0.020    0.848    0.003
# 321    0.030    0.002    0.194    0.002    0.772
# 322    0.008    0.008    0.335    0.550    0.100
#
# [323 rows x 5 columns]

# %%
Emminem.apply(np.mean,axis=0).sort_values()
# Out:
# topic 1    0.085551
# topic 3    0.091573
# topic 2    0.138325
# topic 5    0.318427
# topic 4    0.366142
# dtype: float64

# %%
df_lyrics.groupby('artist').count().index
# Out:
# Index(['A Tribe Called Quest', 'Anthrax', 'Black Star', 'Bob Dylan',
#        'Britney Spears', 'Bruce Springsteen', 'Cannibal Corpse',
#        'Carly Rae Jepsen', 'De La Soul', 'Deicide', 'Dr. Dre', 'Dua Lipa',
#        'Eminem', 'Faith No More', 'Ghostface Killah', 'Gorgoroth', 'Immortal',
#        'Incubus', 'Iron Maiden', 'Kanye West', 'Kendrick Lamar', 'Killer Mike',
#        'Kiss', 'Led Zeppelin', 'Lorde', 'MF Doom', 'Mayhem', 'Megadeth',
#        'Meshuggah', 'Metallica', 'Method Man', 'Michael Jackson', 'Mobb Deep',
#        'Modest Mouse', 'Mos Def', 'Necrophagist', 'Nickelback', 'Nicki Minaj',
#        'Oasis', 'Opeth', 'Pink Floyd', 'Public Enemy', 'Queen', 'Radiohead',
#        'Raekwon', 'Rage Against The Machine', 'Red Hot Chili Peppers', 'Rush',
#        'SIA', 'Sam Smith', 'Slayer', 'Spice Girls', 'System of a Down',
#        'The Beatles', 'The Clash', 'The Doors', 'The Smashing Pumpkins',
#        'The Smiths', 'Tool', 'Vital Remains', 'Weezer'],
#       dtype='object', name='artist')
