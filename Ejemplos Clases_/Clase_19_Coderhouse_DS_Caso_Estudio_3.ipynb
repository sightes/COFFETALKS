# %% [markdown]
# <a href="https://colab.research.google.com/github/sightes/COFFETALKS/blob/main/Clase_19_Coderhouse_DS_Caso_Estudio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DESCARGAMOS EL ARCHIVO

# !wget "https://drive.google.com/u/2/uc?id=1KL6GLCbHh3lRCKFa2SQGx-QBcQh-SK9d&export=download" -O BigMartSales.csv
#https://www.kaggle.com/devendra45/big-mart-sales-prediction-with-xgboost/notebook
#https://www.kaggle.com/brijbhushannanda1979/bigmart-sales-data
# Out:
# --2022-01-18 03:26:06--  https://drive.google.com/u/2/uc?id=1KL6GLCbHh3lRCKFa2SQGx-QBcQh-SK9d&export=download
# Resolving drive.google.com (drive.google.com)... 172.217.193.113, 172.217.193.139, 172.217.193.100, ...
# Connecting to drive.google.com (drive.google.com)|172.217.193.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-30-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/o5anh7urfmpb0p8i8bm6f9f71vequl25/1642476300000/18340134811011616317/*/1KL6GLCbHh3lRCKFa2SQGx-QBcQh-SK9d?e=download [following]
# ...
# --2022-01-18 03:26:07--  https://doc-00-30-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/o5anh7urfmpb0p8i8bm6f9f71vequl25/1642476300000/18340134811011616317/*/1KL6GLCbHh3lRCKFa2SQGx-QBcQh-SK9d?e=download
# Resolving doc-00-30-docs.googleusercontent.com (doc-00-30-docs.googleusercontent.com)... 172.217.203.132, 2607:f8b0:400c:c07::84
# ...

# %%
#IMPORTAMOS LIBRERIAS
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error as mse
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
import pandas as pd 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

##LEEMOS DATOS
df=pd.read_csv('BigMartSales.csv',sep=',')
x=df.drop(columns=['Item_Outlet_Sales','Item_Identifier','Outlet_Establishment_Year','Item_MRP', 'Item_Weight','Outlet_Size'],axis=1)
y=df['Item_Outlet_Sales']
x = pd.get_dummies(x)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(np.sqrt(mse(y_test,y_pred)))
# Out:
# 1413.9250043421937

# %%
plt.plot(y_pred[1:50])
plt.plot(y_test.values[1:50])

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=200,min_samples_split=7,random_state=42,
                         max_depth=15)
# rf --> random forest
rf.fit(x_train,y_train)
y_pred =rf.predict(x_test)
print(np.sqrt(mse(y_test,y_pred)))
# Out:
# 1519.647086449691
